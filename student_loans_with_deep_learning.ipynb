# %% [markdown]
# <a href="https://colab.research.google.com/github/MF-MSB/neural-network-challenge-1/blob/main/student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column

y = loans_df["credit_ranking"]

# Display a sample of y

y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: credit_ranking, Length: 1599, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking

X = loans_df.drop(columns=["credit_ranking"])

# Review the features DataFrame

X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance

X_scaler = StandardScaler()

# Fit the scaler to the features training dataset

X_scaler.fit(X_train)

# Scale the data

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model

input_nodes = len(X_train.columns)

# Review the number of features

input_nodes
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer

hidden_nodes_layer1 =  6

# Define the number of hidden nodes for the second hidden layer

hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer

output_neurons = 1

# %%
# Create the Sequential model instance

nn_model = tf.keras.models.Sequential()

# Add the first hidden layer

nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=input_nodes, activation="relu"))

# Add the second hidden layer

nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function

nn_model.add(tf.keras.layers.Dense(output_neurons, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 6)                 72
#
#  dense_4 (Dense)             (None, 3)                 21
#
#  dense_5 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model

nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data

fit_model = nn_model.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 2ms/step - loss: 0.8244 - accuracy: 0.4954
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7465 - accuracy: 0.5455
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7057 - accuracy: 0.5796
# Epoch 4/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6838 - accuracy: 0.6072
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6701 - accuracy: 0.6447
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6588 - accuracy: 0.6631
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.6856
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6392 - accuracy: 0.7006
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6301 - accuracy: 0.7081
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6226 - accuracy: 0.7139
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6158 - accuracy: 0.7239
# Epoch 12/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.7264
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6026 - accuracy: 0.7323
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5972 - accuracy: 0.7331
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5923 - accuracy: 0.7381
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5878 - accuracy: 0.7373
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.7389
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.7389
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5760 - accuracy: 0.7406
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5724 - accuracy: 0.7448
# Epoch 21/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5694 - accuracy: 0.7490
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5665 - accuracy: 0.7506
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7523
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7473
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5583 - accuracy: 0.7515
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5560 - accuracy: 0.7498
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5539 - accuracy: 0.7515
# Epoch 28/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5519 - accuracy: 0.7506
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5501 - accuracy: 0.7531
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.7540
# Epoch 31/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5460 - accuracy: 0.7573
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7590
# Epoch 33/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.7581
# Epoch 34/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5404 - accuracy: 0.7556
# Epoch 35/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7573
# Epoch 36/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7598
# Epoch 37/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5350 - accuracy: 0.7631
# Epoch 38/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.7615
# Epoch 39/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5318 - accuracy: 0.7581
# Epoch 40/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5304 - accuracy: 0.7631
# Epoch 41/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5290 - accuracy: 0.7648
# Epoch 42/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7665
# Epoch 43/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5262 - accuracy: 0.7673
# Epoch 44/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5247 - accuracy: 0.7665
# Epoch 45/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5235 - accuracy: 0.7681
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5224 - accuracy: 0.7681
# Epoch 47/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5215 - accuracy: 0.7715
# Epoch 48/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.7698
# Epoch 49/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5190 - accuracy: 0.7681
# Epoch 50/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5182 - accuracy: 0.7715

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data

model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results

print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 1s - loss: 0.5568 - accuracy: 0.7525 - 522ms/epoch - 40ms/step
# Loss: 0.5567947626113892, Accuracy: 0.7524999976158142

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# Specify the path to your Google Drive folder
file_path = '/content/gdrive/My Drive/Your_Model_Folder/model.keras'

# Save your model
nn_model.save(file_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# # Set the model's file path
# file_path = 'https://github.com/MF-MSB/neural-network-challenge-1./content/.git'

# # Export your model to a keras file
# nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path

file_path = '/content/gdrive/My Drive/Your_Model_Folder/model.keras'

# Load the model to a new object

nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data

predictions = nn_imported.predict(X_test_scaled,verbose=2)

# Display a sample of the predictions

predictions
# Out:
# 13/13 - 0s - 245ms/epoch - 19ms/step
# array([[0.53917885],
#        [0.5201295 ],
#        [0.7413299 ],
#        [0.70594555],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.125991  ],
#        [0.672302  ],
#        [0.438358  ],
#        [0.66992694],
#        [0.22189939],
#        [0.5785045 ],
#        [0.7413299 ],
#        [0.72738826],
#        [0.41046524],
#        [0.7413299 ],
#        [0.37385482],
#        [0.6190231 ],
#        [0.28929293],
#        [0.7195006 ],
#        [0.7413299 ],
#        [0.2296225 ],
#        [0.71828115],
#        [0.54902285],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.6729884 ],
#        [0.33973917],
#        [0.15384114],
#        [0.6604207 ],
#        [0.7413299 ],
#        [0.2803697 ],
#        [0.7413299 ],
#        [0.17681293],
#        [0.5967118 ],
#        [0.14533645],
#        [0.36296263],
#        [0.7413299 ],
#        [0.17424573],
#        [0.7413299 ],
#        [0.07976864],
#        [0.10169525],
#        [0.7413299 ],
#        [0.07512008],
#        [0.7413299 ],
#        [0.20148169],
#        [0.4630043 ],
#        [0.40068942],
#        [0.7413299 ],
#        [0.09975956],
#        [0.08353987],
#        [0.7413299 ],
#        [0.03666672],
#        [0.17078763],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.38054034],
#        [0.7413299 ],
#        [0.11689845],
#        [0.30598626],
#        [0.5744156 ],
#        [0.02295992],
#        [0.35114685],
#        [0.7311884 ],
#        [0.558589  ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.17681293],
#        [0.7413299 ],
#        [0.7143885 ],
#        [0.5165196 ],
#        [0.12631294],
#        [0.4766195 ],
#        [0.7413299 ],
#        [0.04905735],
#        [0.18029387],
#        [0.7114699 ],
#        [0.7413299 ],
#        [0.11782987],
#        [0.06609815],
#        [0.61311436],
#        [0.7413299 ],
#        [0.13093273],
#        [0.266371  ],
#        [0.7413299 ],
#        [0.31093374],
#        [0.7413299 ],
#        [0.32830536],
#        [0.7413299 ],
#        [0.12355318],
#        [0.7413299 ],
#        [0.5618143 ],
#        [0.2890197 ],
#        [0.7413299 ],
#        [0.7081252 ],
#        [0.66901547],
#        [0.7413299 ],
#        [0.7203548 ],
#        [0.1753365 ],
#        [0.23803443],
#        [0.05979244],
#        [0.10717306],
#        [0.5779847 ],
#        [0.7413299 ],
#        [0.62143725],
#        [0.7413299 ],
#        [0.02376708],
#        [0.7413299 ],
#        [0.7271893 ],
#        [0.60128707],
#        [0.5503948 ],
#        [0.34790185],
#        [0.7413299 ],
#        [0.272288  ],
#        [0.05326189],
#        [0.28630358],
#        [0.2146108 ],
#        [0.07007925],
#        [0.7413299 ],
#        [0.63170224],
#        [0.22446084],
#        [0.22585775],
#        [0.62994206],
#        [0.7413299 ],
#        [0.1757881 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.4668724 ],
#        [0.1767307 ],
#        [0.7413299 ],
#        [0.11909568],
#        [0.7413299 ],
#        [0.66314024],
#        [0.10259425],
#        [0.7413299 ],
#        [0.36538696],
#        [0.3769669 ],
#        [0.36274403],
#        [0.64295894],
#        [0.65440744],
#        [0.15675445],
#        [0.68801606],
#        [0.7413299 ],
#        [0.37158585],
#        [0.02178875],
#        [0.64155453],
#        [0.73631746],
#        [0.41895828],
#        [0.7413299 ],
#        [0.1797162 ],
#        [0.28721187],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7120701 ],
#        [0.7413299 ],
#        [0.5811869 ],
#        [0.44653094],
#        [0.14668536],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.55741733],
#        [0.11996062],
#        [0.10813954],
#        [0.7341214 ],
#        [0.2736978 ],
#        [0.7179109 ],
#        [0.13675103],
#        [0.607372  ],
#        [0.7413299 ],
#        [0.2942776 ],
#        [0.4259696 ],
#        [0.2813153 ],
#        [0.33706045],
#        [0.2890197 ],
#        [0.59461665],
#        [0.7413299 ],
#        [0.54422396],
#        [0.1402921 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.48283935],
#        [0.3935432 ],
#        [0.10834478],
#        [0.3832885 ],
#        [0.7413299 ],
#        [0.45555222],
#        [0.21075849],
#        [0.7413299 ],
#        [0.39614284],
#        [0.6562396 ],
#        [0.11170707],
#        [0.2773141 ],
#        [0.33508834],
#        [0.7413299 ],
#        [0.46731132],
#        [0.72376263],
#        [0.09570765],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.25033498],
#        [0.0551696 ],
#        [0.7413299 ],
#        [0.71660364],
#        [0.39943215],
#        [0.59576637],
#        [0.23803443],
#        [0.7413299 ],
#        [0.37947983],
#        [0.17027919],
#        [0.10483052],
#        [0.129601  ],
#        [0.7413299 ],
#        [0.67438895],
#        [0.614345  ],
#        [0.23391306],
#        [0.45454794],
#        [0.10719869],
#        [0.7274451 ],
#        [0.70031524],
#        [0.6965691 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.3160104 ],
#        [0.33687434],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.2628623 ],
#        [0.1375599 ],
#        [0.7413299 ],
#        [0.27517858],
#        [0.24557255],
#        [0.5241234 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.50949657],
#        [0.7087735 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.50497615],
#        [0.11702713],
#        [0.31961247],
#        [0.2315668 ],
#        [0.23019528],
#        [0.7413299 ],
#        [0.6904111 ],
#        [0.70124114],
#        [0.11090397],
#        [0.0813623 ],
#        [0.2376793 ],
#        [0.48816437],
#        [0.7225498 ],
#        [0.7413299 ],
#        [0.15192528],
#        [0.6300942 ],
#        [0.40627435],
#        [0.5630679 ],
#        [0.64155453],
#        [0.666224  ],
#        [0.10558083],
#        [0.1368997 ],
#        [0.7413299 ],
#        [0.3166546 ],
#        [0.74113643],
#        [0.17760451],
#        [0.7413299 ],
#        [0.0747272 ],
#        [0.7413299 ],
#        [0.44911578],
#        [0.7179109 ],
#        [0.456963  ],
#        [0.23859444],
#        [0.7413299 ],
#        [0.57892704],
#        [0.5651698 ],
#        [0.06296735],
#        [0.27167276],
#        [0.69284546],
#        [0.5580765 ],
#        [0.10439491],
#        [0.14705405],
#        [0.6926268 ],
#        [0.7014904 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.6323178 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.12434114],
#        [0.7413299 ],
#        [0.09888018],
#        [0.16242927],
#        [0.39689574],
#        [0.7413299 ],
#        [0.21718739],
#        [0.7394914 ],
#        [0.26776823],
#        [0.6165926 ],
#        [0.07740776],
#        [0.7413299 ],
#        [0.44192603],
#        [0.03041707],
#        [0.12134071],
#        [0.684673  ],
#        [0.22508398],
#        [0.4760113 ],
#        [0.7089934 ],
#        [0.73585975],
#        [0.28408715],
#        [0.28653306],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.4825914 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.14802358],
#        [0.39614284],
#        [0.50859874],
#        [0.06910639],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.52498627],
#        [0.7413299 ],
#        [0.12311753],
#        [0.40464714],
#        [0.6162888 ],
#        [0.610444  ],
#        [0.15450914],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.26632723],
#        [0.62908864],
#        [0.2278437 ],
#        [0.16881466],
#        [0.46517816],
#        [0.6480312 ],
#        [0.42820454],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.4323471 ],
#        [0.19320564],
#        [0.5251198 ],
#        [0.5957664 ],
#        [0.7413299 ],
#        [0.7113942 ],
#        [0.7413299 ],
#        [0.45834062],
#        [0.26975465],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.10259425],
#        [0.08231428],
#        [0.23204504],
#        [0.7162439 ],
#        [0.26642397],
#        [0.7413299 ],
#        [0.36992693],
#        [0.12811583],
#        [0.38485217],
#        [0.30230543],
#        [0.7413299 ],
#        [0.1375599 ],
#        [0.56950516],
#        [0.56189317],
#        [0.42254186],
#        [0.16849843],
#        [0.13446723],
#        [0.69577134],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.17027919],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.7413299 ],
#        [0.23856068],
#        [0.7413299 ],
#        [0.19384645],
#        [0.5977361 ],
#        [0.7413299 ],
#        [0.69712096],
#        [0.23137136],
#        [0.28263226],
#        [0.3766394 ],
#        [0.7413299 ],
#        [0.16665345],
#        [0.7413299 ],
#        [0.31093374],
#        [0.7413299 ],
#        [0.41889665],
#        [0.6512063 ]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results

predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       188
#            1       0.76      0.78      0.77       212
#
#     accuracy                           0.75       400
#    macro avg       0.75      0.75      0.75       400
# weighted avg       0.75      0.75      0.75       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
